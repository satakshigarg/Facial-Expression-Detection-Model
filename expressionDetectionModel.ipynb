# %% [markdown]
# <a href="https://colab.research.google.com/github/satakshigarg/Facial-Expression-Detection-Model/blob/main/expressionDetectionModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install deepface

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
from google.colab import drive
drive.mount('/content/drive')
img = cv2.imread('/content/drive/MyDrive/proSmile.jpg')
plt.imshow(img[:,:,::-1])
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
result = DeepFace.analyze(img, actions = ['emotion'])

# %%
print(result)
# Out:
# {'emotion': {'angry': 0.00040155628084903583, 'disgust': 2.1391683979743448e-07, 'fear': 67.73608326911926, 'happy': 3.8675103336572647, 'sad': 28.229737281799316, 'surprise': 0.040011576493270695, 'neutral': 0.12625984381884336}, 'dominant_emotion': 'fear'}
